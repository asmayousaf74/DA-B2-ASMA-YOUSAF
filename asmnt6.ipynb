# %%
# !pip install pandas

# %%
import pandas as pd

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_built_with_meson',
#  '_config',
# ...

# %%
df = pd.read_csv('compensation data.csv')
df
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 0            124267
# 1            236889
# 2             74321
# 3             62593
# ...

# %%
df.shape
# Out:
# (25973, 6)

# %%
df.shape[0]
# Out:
# 25973

# %%
df.shape[1]
# Out:
# 6

# %%
df.info
# Out:
# <bound method DataFrame.info of        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 0            124267
# 1            236889
# 2             74321
# ...

# %%
df.dtypes
# Out:
# experience_coding    float64
# python_user             bool
# r_user                  bool
# sql_user                bool
# most_used             object
# compensation           int64
# dtype: object

# %%
df.head
# Out:
# <bound method NDFrame.head of        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 0            124267
# 1            236889
# 2             74321
# ...

# %%
df.tail
# Out:
# <bound method NDFrame.tail of        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 0            124267
# 1            236889
# 2             74321
# ...

# %%
df.head(35)
# Out:
#     experience_coding  python_user  r_user  sql_user     most_used  \
# 0                6.10         True   False      True  Scikit-learn
# 1               12.30         True    True      True  Scikit-learn
# 2                2.20         True   False     False           NaN
# 3                2.70        False   False      True           NaN
# 4                1.20         True   False     False  Scikit-learn
# 5                1.00         True   False     False       PyTorch
# 6                1.80        False   False     False           NaN
# 7                6.10         True   False     False    TensorFlow
# 8                4.50         True   False      True  Scikit-learn
# 9                1.10         True   False      True    TensorFlow
# 10               2.70         True    True      True           NaN
# 11               0.93         True    True     False  Scikit-learn
# 12               0.32         True   False     False           NaN
# ...

# %%
df.tail(25)
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 25948              10.00         True   False      True    TensorFlow
# 25949               9.80         True    True      True       PyTorch
# 25950               0.39         True    True      True           NaN
# 25951               2.80         True   False     False    TensorFlow
# 25952               1.40         True   False     False  Scikit-learn
# 25953               0.78        False   False     False           NaN
# 25954               0.77         True   False     False           NaN
# 25955               4.90         True   False      True    TensorFlow
# 25956              10.70         True   False     False           NaN
# 25957               3.90         True   False      True           NaN
# 25958               1.30         True    True     False         Keras
# 25959               1.60         True   False      True    TensorFlow
# ...

# %%
df.loc[2]
# Out:
# experience_coding      2.2
# python_user           True
# r_user               False
# sql_user             False
# most_used              NaN
# compensation         74321
# Name: 2, dtype: object

# %%
df.loc[2,'r_user']
# Out:
# False

# %%
df.iloc[45]
# Out:
# experience_coding       3.1
# python_user            True
# r_user                False
# sql_user              False
# most_used             Keras
# compensation         114807
# Name: 45, dtype: object

# %%
df.iloc[45,4]
# Out:
# 'Keras'

# %%
df.loc[4:23]
# Out:
#     experience_coding  python_user  r_user  sql_user     most_used  \
# 4                1.20         True   False     False  Scikit-learn
# 5                1.00         True   False     False       PyTorch
# 6                1.80        False   False     False           NaN
# 7                6.10         True   False     False    TensorFlow
# 8                4.50         True   False      True  Scikit-learn
# 9                1.10         True   False      True    TensorFlow
# 10               2.70         True    True      True           NaN
# 11               0.93         True    True     False  Scikit-learn
# 12               0.32         True   False     False           NaN
# 13               9.90         True   False      True  Scikit-learn
# 14               0.78         True   False     False    TensorFlow
# 15              13.50         True   False     False  Scikit-learn
# 16              26.50         True   False      True  Scikit-learn
# ...

# %%
df.iloc[56:65]
# Out:
#     experience_coding  python_user  r_user  sql_user     most_used  \
# 56               2.90         True   False     False           NaN
# 57               1.20         True    True     False           NaN
# 58               1.50         True   False      True    TensorFlow
# 59               1.80         True   False      True  Scikit-learn
# 60               0.91        False   False     False  Scikit-learn
# 61               4.50         True   False     False           NaN
# 62               1.60         True   False      True  Scikit-learn
# 63               0.27         True   False     False           NaN
# 64               2.60         True   False     False  Scikit-learn
#
#     compensation
# 56         74321
# 57           671
# 58           837
# 59          2011
# 60         62937
# 61           685
# 62         41615
# 63         52572
# 64         51856

# %%
df.iloc[56:65,:3]
# Out:
#     experience_coding  python_user  r_user
# 56               2.90         True   False
# 57               1.20         True    True
# 58               1.50         True   False
# 59               1.80         True   False
# 60               0.91        False   False
# 61               4.50         True   False
# 62               1.60         True   False
# 63               0.27         True   False
# 64               2.60         True   False

# %%
df.loc[45:55,:'most_used']
# Out:
#     experience_coding  python_user  r_user  sql_user     most_used
# 45               3.10         True   False     False         Keras
# 46               0.26         True   False      True  Scikit-learn
# 47               2.10         True    True     False  Scikit-learn
# 48               4.40         True   False      True         Keras
# 49               5.20         True    True     False  Scikit-learn
# 50               0.70         True    True      True    TensorFlow
# 51               0.69        False   False     False           NaN
# 52               1.30        False    True      True           NaN
# 53               1.50         True   False      True  Scikit-learn
# 54               2.20        False   False      True           NaN
# 55               6.30        False   False     False    TensorFlow

# %%
df1 = pd.read_csv('compensation data.csv',index_col=5)
df1
# Out:
#               experience_coding  python_user  r_user  sql_user     most_used
# compensation
# 124267                      6.1         True   False      True  Scikit-learn
# 236889                     12.3         True    True      True  Scikit-learn
# 74321                       2.2         True   False     False           NaN
# 62593                       2.7        False   False      True           NaN
# 36288                       1.2         True   False     False  Scikit-learn
# ...                         ...          ...     ...       ...           ...
# 15800                       1.9         True   False      True  Scikit-learn
# 62456                       1.4         True   False     False       PyTorch
# 923                         0.0        False   False     False           NaN
# 60609                       9.4         True   False      True  Scikit-learn
# 493                         0.0        False   False     False           NaN
#
# [25973 rows x 5 columns]

# %%
df.iloc[[4,10,67,88,99,112]]
# Out:
#      experience_coding  python_user  r_user  sql_user     most_used  \
# 4                 1.20         True   False     False  Scikit-learn
# 10                2.70         True    True      True           NaN
# 67                2.70         True   False     False    TensorFlow
# 88                1.50         True   False      True           NaN
# 99                0.98         True   False      True           NaN
# 112               2.30         True   False     False    TensorFlow
#
#      compensation
# 4           36288
# 10          70564
# 67           8181
# 88          73043
# 99          58465
# 112         54427

# %%
df.loc[[4,7],['r_user','sql_user']]
# Out:
#    r_user  sql_user
# 4   False     False
# 7   False     False

# %%
df['python_user']
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4         True
#          ...
# 25968     True
# 25969     True
# 25970    False
# 25971     True
# 25972    False
# Name: python_user, Length: 25973, dtype: bool

# %%
df.drop('sql_user', axis =1,inplace = True)

# %%
df
# Out:
#        experience_coding  python_user  r_user     most_used  compensation
# 0                    6.1         True   False  Scikit-learn        124267
# 1                   12.3         True    True  Scikit-learn        236889
# 2                    2.2         True   False           NaN         74321
# 3                    2.7        False   False           NaN         62593
# 4                    1.2         True   False  Scikit-learn         36288
# ...                  ...          ...     ...           ...           ...
# 25968                1.9         True   False  Scikit-learn         15800
# 25969                1.4         True   False       PyTorch         62456
# 25970                0.0        False   False           NaN           923
# 25971                9.4         True   False  Scikit-learn         60609
# 25972                0.0        False   False           NaN           493
#
# [25973 rows x 5 columns]

# %%
df
# Out:
#        experience_coding  python_user  r_user     most_used  compensation
# 0                    6.1         True   False  Scikit-learn        124267
# 1                   12.3         True    True  Scikit-learn        236889
# 2                    2.2         True   False           NaN         74321
# 3                    2.7        False   False           NaN         62593
# 4                    1.2         True   False  Scikit-learn         36288
# ...                  ...          ...     ...           ...           ...
# 25968                1.9         True   False  Scikit-learn         15800
# 25969                1.4         True   False       PyTorch         62456
# 25970                0.0        False   False           NaN           923
# 25971                9.4         True   False  Scikit-learn         60609
# 25972                0.0        False   False           NaN           493
#
# [25973 rows x 5 columns]

# %%
df.drop(25970,inplace=True)

# %%
df
# Out:
#        experience_coding  python_user  r_user     most_used  compensation
# 0                    6.1         True   False  Scikit-learn        124267
# 1                   12.3         True    True  Scikit-learn        236889
# 2                    2.2         True   False           NaN         74321
# 3                    2.7        False   False           NaN         62593
# 4                    1.2         True   False  Scikit-learn         36288
# ...                  ...          ...     ...           ...           ...
# 25967                6.1         True   False  Scikit-learn         80090
# 25968                1.9         True   False  Scikit-learn         15800
# 25969                1.4         True   False       PyTorch         62456
# 25971                9.4         True   False  Scikit-learn         60609
# 25972                0.0        False   False           NaN           493
#
# [25971 rows x 5 columns]

# %%
df2 = pd.read_csv('compensation data.csv',header = None)

# %%
df2
# Out:
#                        0            1       2         3             4  \
# 0      experience_coding  python_user  r_user  sql_user     most_used
# 1                    6.1         TRUE   FALSE      TRUE  Scikit-learn
# 2                   12.3         TRUE    TRUE      TRUE  Scikit-learn
# 3                    2.2         TRUE   FALSE     FALSE           NaN
# 4                    2.7        FALSE   FALSE      TRUE           NaN
# ...                  ...          ...     ...       ...           ...
# 25969                1.9         TRUE   FALSE      TRUE  Scikit-learn
# 25970                1.4         TRUE   FALSE     FALSE       PyTorch
# 25971                  0        FALSE   FALSE     FALSE           NaN
# 25972                9.4         TRUE   FALSE      TRUE  Scikit-learn
# 25973                  0        FALSE   FALSE     FALSE           NaN
#
#                   5
# 0      compensation
# 1            124267
# 2            236889
# 3             74321
# ...

# %%
df['r_user'] == 'True'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25967    False
# 25968    False
# 25969    False
# 25971    False
# 25972    False
# Name: r_user, Length: 25971, dtype: bool

# %%
df[df['r_user'] == 'True']
# Out:
# Empty DataFrame
# Columns: [experience_coding, python_user, r_user, most_used, compensation]
# Index: []

# %%
df[(df['python_user'] == True) & (df['most_used'] == 'Scikit-learn')]
# Out:
#        experience_coding  python_user  r_user     most_used  compensation
# 0                   6.10         True   False  Scikit-learn        124267
# 1                  12.30         True    True  Scikit-learn        236889
# 4                   1.20         True   False  Scikit-learn         36288
# 8                   4.50         True   False  Scikit-learn         55418
# 11                  0.93         True    True  Scikit-learn         55525
# ...                  ...          ...     ...           ...           ...
# 25952               1.40         True   False  Scikit-learn         17757
# 25966               1.90         True   False  Scikit-learn          3932
# 25967               6.10         True   False  Scikit-learn         80090
# 25968               1.90         True   False  Scikit-learn         15800
# 25971               9.40         True   False  Scikit-learn         60609
#
# [7592 rows x 5 columns]

# %%
df['most_used'].unique()
# Out:
# array(['Scikit-learn', nan, 'PyTorch', 'TensorFlow', 'Keras'],
#       dtype=object)

# %%
df[df['most_used'] == 'PyTorch']
# Out:
#        experience_coding  python_user  r_user most_used  compensation
# 5                    1.0         True   False   PyTorch         61302
# 18                   3.4         True   False   PyTorch         73527
# 81                   6.6         True   False   PyTorch         57861
# 89                  28.2         True   False   PyTorch        268191
# 96                   1.7         True   False   PyTorch         10284
# ...                  ...          ...     ...       ...           ...
# 25949                9.8         True    True   PyTorch         90950
# 25960               17.8         True   False   PyTorch         41513
# 25961                3.7         True   False   PyTorch         65027
# 25963               25.4         True   False   PyTorch        483648
# 25969                1.4         True   False   PyTorch         62456
#
# [2445 rows x 5 columns]

# %%
df[(df['most_used'] == 'PyTorch') |(df['most_used'] == 'Scikit-learn')]
# Out:
#        experience_coding  python_user  r_user     most_used  compensation
# 0                    6.1         True   False  Scikit-learn        124267
# 1                   12.3         True    True  Scikit-learn        236889
# 4                    1.2         True   False  Scikit-learn         36288
# 5                    1.0         True   False       PyTorch         61302
# 8                    4.5         True   False  Scikit-learn         55418
# ...                  ...          ...     ...           ...           ...
# 25966                1.9         True   False  Scikit-learn          3932
# 25967                6.1         True   False  Scikit-learn         80090
# 25968                1.9         True   False  Scikit-learn         15800
# 25969                1.4         True   False       PyTorch         62456
# 25971                9.4         True   False  Scikit-learn         60609
#
# [10378 rows x 5 columns]

# %%
df[(df['most_used'] == 'PyTorch') &~ (df['most_used'] == 'Scikit-learn')]
# Out:
#        experience_coding  python_user  r_user most_used  compensation
# 5                    1.0         True   False   PyTorch         61302
# 18                   3.4         True   False   PyTorch         73527
# 81                   6.6         True   False   PyTorch         57861
# 89                  28.2         True   False   PyTorch        268191
# 96                   1.7         True   False   PyTorch         10284
# ...                  ...          ...     ...       ...           ...
# 25949                9.8         True    True   PyTorch         90950
# 25960               17.8         True   False   PyTorch         41513
# 25961                3.7         True   False   PyTorch         65027
# 25963               25.4         True   False   PyTorch        483648
# 25969                1.4         True   False   PyTorch         62456
#
# [2445 rows x 5 columns]

# %%
df.python_user
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4         True
#          ...
# 25967     True
# 25968     True
# 25969     True
# 25971     True
# 25972    False
# Name: python_user, Length: 25971, dtype: bool

# %%
df[df.python_user]
# Out:
#        experience_coding  python_user  r_user     most_used  compensation
# 0                    6.1         True   False  Scikit-learn        124267
# 1                   12.3         True    True  Scikit-learn        236889
# 2                    2.2         True   False           NaN         74321
# 4                    1.2         True   False  Scikit-learn         36288
# 5                    1.0         True   False       PyTorch         61302
# ...                  ...          ...     ...           ...           ...
# 25966                1.9         True   False  Scikit-learn          3932
# 25967                6.1         True   False  Scikit-learn         80090
# 25968                1.9         True   False  Scikit-learn         15800
# 25969                1.4         True   False       PyTorch         62456
# 25971                9.4         True   False  Scikit-learn         60609
#
# [21859 rows x 5 columns]
